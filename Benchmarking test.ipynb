# %%
import deepchem
import deepchem as dc
import run_benchmark
import tensorflow as tf
print(f'deepchem version:\t{deepchem.__version__}')

print(f'tensorflow version:\t{tf.__version__}')
# Out:
# deepchem version:	2.5.0
# tensorflow version:	2.7.0

# %%
model_list_classification=[
      'rf', 'tf', 'tf_robust', 'logreg', 'irv', 'graphconv', 'dag', 'xgb',
      'weave', 'kernelsvm', 'textcnn', 'mpnn'
  ]

# %%
dir(run_benchmark)
# Out:
# ['CheckFeaturizer',
#  'CheckSplit',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'benchmark_classification',
#  'benchmark_model',
#  'benchmark_regression',
#  'csv',
#  'deepchem',
#  'hps',
#  'load_dataset',
#  'np',
#  'os',
#  'pickle',
#  'run_benchmark',
#  'time']

# %%
run_benchmark.run_benchmark(datasets=['bbbp','tox21'], model='graphconv', test=True)
# Out:
# Failed to featurize datapoint 59, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 61, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# -------------------------------------
# Benchmark on dataset: bbbp
# -------------------------------------
# Failed to featurize datapoint 391, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
# ...

# %%
run_benchmark.run_benchmark(datasets=['bbbp','tox21'], model='tf', test=True)
# Out:
# -------------------------------------
# Benchmark on dataset: bbbp
# -------------------------------------
# -------------------------------------
# Benchmark on dataset: tox21
# -------------------------------------

# %%
run_benchmark.run_benchmark(datasets=['bbbp','tox21'], model='logreg', test=True)
# Out:
# -------------------------------------
# Benchmark on dataset: bbbp
# -------------------------------------
# -------------------------------------
# Benchmark on dataset: tox21
# -------------------------------------

# %%
run_benchmark.run_benchmark(datasets=['bbbp','tox21'], model='dag', test=True)
# Out:
# -------------------------------------
# Benchmark on dataset: bbbp
# -------------------------------------
# Maximum number of atoms: 60
# -------------------------------------
# Benchmark on dataset: tox21
# -------------------------------------
# Maximum number of atoms: 60

# %%
run_benchmark.run_benchmark(datasets=['bbbp','tox21'], model='weave', test=True)
# Out:
# -------------------------------------
# Benchmark on dataset: bbbp
# -------------------------------------
# Failed to featurize datapoint 59, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 61, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 391, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
# ...

# %%
# !pip install xgboost

# %%
run_benchmark.run_benchmark(datasets=['qm7','qm8'], model='tf_regression', test=True)
# Out:
# -------------------------------------
# Benchmark on dataset: qm7
# -------------------------------------
# -----------------------------
# Start fitting: tf_regression
# -------------------------------------
# Benchmark on dataset: qm8
# -------------------------------------
# -----------------------------
# Start fitting: tf_regression

# %%
run_benchmark.run_benchmark(datasets=['qm7','qm8'], model='krr', test=True)
# Out:
# -------------------------------------
# Benchmark on dataset: qm7
# -------------------------------------
# -----------------------------
# Start fitting: krr
# -------------------------------------
# Benchmark on dataset: qm8
# -------------------------------------
# -----------------------------
# Start fitting: krr

# %%
run_benchmark.run_benchmark(datasets=['qm7','qm8'], model='graphconvreg', test=True)
# Out:
# -------------------------------------
# Benchmark on dataset: qm7
# -------------------------------------
# -----------------------------
# Start fitting: graphconvreg
# C:\Users\eg16993\Anaconda3\envs\tdaf-tf2p7\lib\site-packages\tensorflow\python\framework\indexed_slices.py:450: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_2/graph_pool_5/Reshape_14:0", shape=(1135,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_2/graph_pool_5/Reshape_13:0", shape=(1135, 128), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_2/graph_pool_5/Cast_4:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# ...

# %%
run_benchmark.run_benchmark(datasets=['qm7','qm8'], model='weave_regression', test=True)
# Out:
# -------------------------------------
# Benchmark on dataset: qm7
# -------------------------------------
# -----------------------------
# Start fitting: weave_regression
# WARNING:tensorflow:Gradients do not exist for variables ['weave_layer_5/kernel:0', 'weave_layer_5/Variable:0', 'weave_layer_5/kernel:0', 'weave_layer_5/Variable:0', 'weave_layer_5/kernel:0', 'weave_layer_5/Variable:0', 'weave_layer_5/batch_normalization_3/gamma:0', 'weave_layer_5/batch_normalization_3/beta:0', 'weave_layer_5/batch_normalization_4/gamma:0', 'weave_layer_5/batch_normalization_4/beta:0', 'weave_layer_5/batch_normalization_5/gamma:0', 'weave_layer_5/batch_normalization_5/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ...

# %%
run_benchmark.run_benchmark(datasets=['qm7','qm8'], model='tf_regression', test=True)
# Out:
# -------------------------------------
# Benchmark on dataset: qm7
# -------------------------------------
# -----------------------------
# Start fitting: tf_regression
# -------------------------------------
# Benchmark on dataset: qm8
# -------------------------------------
# -----------------------------
# Start fitting: tf_regression
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3616\3128366648.py in <module>
# ----> 1 run_benchmark.run_benchmark(datasets=['qm7','qm8'], model='tf_regression', test=True)
#
# ~\OneDrive - University of Bristol\Documents\GitHub\deepchem\deepchem\molnet\run_benchmark.py in run_benchmark(datasets, model, split, metric, direction, featurizer, n_features, out_path, hyper_parameters, hyper_param_search, max_iter, search_range, test, reload, seed)
#     202             test=test,
# ...

# %%
model_list_regression=[
      'tf_regression', 'tf_regression_ft', 'rf_regression', 'graphconvreg',
      'dtnn', 'dag_regression', 'xgb_regression', 'weave_regression',
      'textcnn_regression', 'krr', 'ani', 'krr_ft', 'mpnn'
  ]
model_list_regression
# Out:
# ['tf_regression',
#  'tf_regression_ft',
#  'rf_regression',
#  'graphconvreg',
#  'dtnn',
#  'dag_regression',
#  'xgb_regression',
#  'weave_regression',
#  'textcnn_regression',
#  'krr',
#  'ani',
#  'krr_ft',
#  'mpnn']

# %%
run_benchmark.run_benchmark(datasets=['qm7','qm8'], model='rf_regression', test=True)
# Out:
# -------------------------------------
# Benchmark on dataset: qm7
# -------------------------------------
# -----------------------------
# Start fitting: rf_regression
# -------------------------------------
# Benchmark on dataset: qm8
# -------------------------------------
# -----------------------------
# Start fitting: rf_regression

# %%
run_benchmark.run_benchmark(datasets=['qm7','qm8'], model='tf_regression_ft', test=True)
# Out:
# -------------------------------------
# Benchmark on dataset: qm7
# -------------------------------------
# C:\Users\eg16993\Anaconda3\envs\tdaf-tf2p7\lib\site-packages\deepchem\feat\molecule_featurizers\coulomb_matrices.py:138: RuntimeWarning: divide by zero encountered in true_divide
#   m = np.outer(z, z) / d
# -----------------------------
# Start fitting: tf_regression_ft
# -------------------------------------
# Benchmark on dataset: qm8
# -------------------------------------
# Failed to featurize datapoint 5620, [H]C([H])([H])C([H])(C([H])([H])[H])C([H])([H])C(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H]. Appending empty array
# Exception message:
# Failed to featurize datapoint 5621, [H]OC(C([H])([H])[H])(C([H])([H])[H])C([H])([H])C([H])(C([H])([H])[H])C([H])([H])[H]. Appending empty array
# Exception message:
# Failed to featurize datapoint 5622, [H]C([H])([H])C([H])(OC(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H])C([H])([H])[H]. Appending empty array
# ...

# %%
run_benchmark.run_benchmark(datasets=['qm7','qm8'], model='graphconvreg', test=True)
# Out:
# -------------------------------------
# Benchmark on dataset: qm7
# -------------------------------------
# -----------------------------
# Start fitting: graphconvreg
# C:\Users\eg16993\Anaconda3\envs\tdaf-tf2p7\lib\site-packages\tensorflow\python\framework\indexed_slices.py:450: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/private__graph_conv_keras_model_4/graph_pool_9/Reshape_14:0", shape=(1163,), dtype=int32), values=Tensor("gradient_tape/private__graph_conv_keras_model_4/graph_pool_9/Reshape_13:0", shape=(1163, 128), dtype=float32), dense_shape=Tensor("gradient_tape/private__graph_conv_keras_model_4/graph_pool_9/Cast_4:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# ...

# %%
run_benchmark.run_benchmark(datasets=['qm7','qm8'], model='dtnn', test=True)
# Out:
# -------------------------------------
# Benchmark on dataset: qm7
# -------------------------------------
# -----------------------------
# Start fitting: dtnn
# C:\Users\eg16993\Anaconda3\envs\tdaf-tf2p7\lib\site-packages\tensorflow\python\framework\indexed_slices.py:450: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_15/dtnn_step_1/Reshape_5:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_15/dtnn_step_1/Reshape_4:0", shape=(None, 60), dtype=float32), dense_shape=Tensor("gradient_tape/model_15/dtnn_step_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# ...

# %%
run_benchmark.run_benchmark(datasets=['qm7','qm8'], model='dag_regression', test=True)

# %%
run_benchmark.run_benchmark(datasets=['qm7','qm8'], model='xgb_regression', test=True)

# %%
run_benchmark.run_benchmark(datasets=['qm7','qm8'], model='textcnn_regression', test=True)
# Out:
# -------------------------------------
# Benchmark on dataset: qm7
# -------------------------------------
# -----------------------------
# Start fitting: textcnn_regression
# -------------------------------------
# Benchmark on dataset: qm8
# -------------------------------------
# -----------------------------
# Start fitting: textcnn_regression

# %%
run_benchmark.run_benchmark(datasets=['qm7','qm8'], model='ani', test=True)
# Out:
# -------------------------------------
# Benchmark on dataset: qm7
# -------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3616\2309058542.py in <module>
# ----> 1 run_benchmark.run_benchmark(datasets=['qm7','qm8'], model='ani', test=True)
#
# ~\OneDrive - University of Bristol\Documents\GitHub\deepchem\deepchem\molnet\run_benchmark.py in run_benchmark(datasets, model, split, metric, direction, featurizer, n_features, out_path, hyper_parameters, hyper_param_search, max_iter, search_range, test, reload, seed)
#     151     else:
#     152       tasks, all_dataset, transformers = loading_functions[dataset](
# --> 153           featurizer=featurizer, reload=reload)
#     154
#     155     train_dataset, valid_dataset, test_dataset = all_dataset
#
# ...

# %%
run_benchmark.run_benchmark(datasets=['qm7','qm8'], model='weave_regression', test=True)
# Out:
# -------------------------------------
# Benchmark on dataset: qm7
# -------------------------------------
# -----------------------------
# Start fitting: weave_regression
# WARNING:tensorflow:Gradients do not exist for variables ['weave_layer_7/kernel:0', 'weave_layer_7/Variable:0', 'weave_layer_7/kernel:0', 'weave_layer_7/Variable:0', 'weave_layer_7/kernel:0', 'weave_layer_7/Variable:0', 'weave_layer_7/batch_normalization_3/gamma:0', 'weave_layer_7/batch_normalization_3/beta:0', 'weave_layer_7/batch_normalization_4/gamma:0', 'weave_layer_7/batch_normalization_4/beta:0', 'weave_layer_7/batch_normalization_5/gamma:0', 'weave_layer_7/batch_normalization_5/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ...

# %%
run_benchmark.run_benchmark(datasets=['qm7','qm8'], model='krr_ft', test=True)
# Out:
# -------------------------------------
# Benchmark on dataset: qm7
# -------------------------------------
# -----------------------------
# Start fitting: krr_ft
# -------------------------------------
# Benchmark on dataset: qm8
# -------------------------------------
# -----------------------------
# Start fitting: krr_ft

# %%
run_benchmark.run_benchmark(datasets=['qm7','qm8'], model='mpnn', test=True)
# Out:
# -------------------------------------
# Benchmark on dataset: qm8
# -------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3616\499546843.py in <module>
# ----> 1 run_benchmark.run_benchmark(datasets=['qm7','qm8'], model='mpnn', test=True)
#
# ~\OneDrive - University of Bristol\Documents\GitHub\deepchem\deepchem\molnet\run_benchmark.py in run_benchmark(datasets, model, split, metric, direction, featurizer, n_features, out_path, hyper_parameters, hyper_param_search, max_iter, search_range, test, reload, seed)
#     151     else:
#     152       tasks, all_dataset, transformers = loading_functions[dataset](
# --> 153           featurizer=featurizer, reload=reload)
#     154
#     155     train_dataset, valid_dataset, test_dataset = all_dataset
#
# ...

# %%
run_benchmark.run_benchmark(datasets=['qm7','qm8'], model='textcnn', test=True)

# %%
run_benchmark.run_benchmark(datasets=['bbbp'], model='kernelsvm', test=True)
# Out:
# -------------------------------------
# Benchmark on dataset: bbbp
# -------------------------------------

# %%
#featurizer = deepchem.feat.RDKitDescriptors()
tasks, datasets, transformers = deepchem.molnet.load_qm7(
    shard_size=2000,
    featurizer=featurizer,
    splitter=None)

# %%
#featurizer = deepchem.feat.RDKitDescriptors()
tasks, datasets, transformers = deepchem.molnet.load_qm7(
    shard_size=2000,
    featurizer=featurizer)
train_dataset, valid_dataset, test_dataset = datasets

# %%
transformers

# %%
n_classes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3616\1992136526.py in <module>
# ----> 1 n_classes
#
# NameError: name 'n_classes' is not defined

# %%
train_dataset, valid_dataset, test_dataset = datasets
# this loads in a general purpose regression model
model = dc.models.MultitaskRegressor(
    n_tasks = len(test_dataset.tasks), # size of y, we have one output task here: finding toxicity
    n_features = len(test_dataset.X[0]), # number of input features, i.e. the length of the ECFPs
    layer_sizes = [1000, 1000],
    weight_init_stddevs = [0.02, 0.02],
    bias_init_consts = [1., 1.],
    dropouts = [0.25, 0.25],
    penalty = 0.0005,
    penalty_type= 'l2',
    batch_size = 128,
    nb_epoch = 50,
    learning_rate=0.0008
)

############################################
# Now we fit the training dataset!         #
############################################
model.fit(train_dataset, nb_epoch=3)
# Out:
# 1.0203017530770138

# %%
# this line tells deepchem what metric to use to score the datasets
metric = dc.metrics.Metric(dc.metrics.mae_score)

# model.evaluate() tests the model. 
# we have to give it the data to use, the metric (or set of metrics) and the transformer used
print('Over all tasks:')
print("Training set score:", model.evaluate(train_dataset, [metric], transformers))
print("Valid set score:", model.evaluate(valid_dataset, [metric], transformers))
print("Test set score:", model.evaluate(test_dataset, [metric], transformers))
ground_truth = test_dataset.y
predictions = model.predict(test_dataset)
metric = dc.metrics.roc_auc_score
# Out:
# Over all tasks:
# Training set score: {'mae_score': 176.49397621143328}
# Valid set score: {'mae_score': 172.71578963537178}
# Test set score: {'mae_score': 178.28029389201666}

# %%
featurizer = deepchem.feat.CoulombMatrix(max_atoms=29)
tasks, datasets, transformers = deepchem.molnet.load_qm7(
    shard_size=2000,
    featurizer=featurizer)
train_dataset, valid_dataset, test_dataset = datasets
metric = dc.metrics.Metric(dc.metrics.mae_score)
run_benchmark.run_benchmark(
    datasets=['qm7'], 
    model='krr_ft', 
    split=None,
    metric=metric, # r2 is default
    direction=True,
    featurizer=None,
    n_features=0,
    out_path='.',
    hyper_parameters=None,
    hyper_param_search=False,
    max_iter=20,
    search_range=2,
    test=True,
    reload=True,
    seed=123)
# Out:
# -------------------------------------
# Benchmark on dataset: qm7
# -------------------------------------
# -----------------------------
# Start fitting: krr_ft

# %%
metric = dc.metrics.Metric(dc.metrics.mae_score)

# model.evaluate() tests the model. 
# we have to give it the data to use, the metric (or set of metrics) and the transformer used
print('Over all tasks:')
print("Training set score:", model.evaluate(train_dataset, [metric], transformers))
print("Valid set score:", model.evaluate(valid_dataset, [metric], transformers))
print("Test set score:", model.evaluate(test_dataset, [metric], transformers))
ground_truth = test_dataset.y
predictions = model.predict(test_dataset)
metric = dc.metrics.roc_auc_score
# Out:
# Over all tasks:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3616\327713349.py in <module>
#       4 # we have to give it the data to use, the metric (or set of metrics) and the transformer used
#       5 print('Over all tasks:')
# ----> 6 print("Training set score:", model.evaluate(train_dataset, [metric], transformers))
#       7 print("Valid set score:", model.evaluate(valid_dataset, [metric], transformers))
#       8 print("Test set score:", model.evaluate(test_dataset, [metric], transformers))
#
# ~\Anaconda3\envs\tdaf-tf2p7\lib\site-packages\deepchem\models\models.py in evaluate(self, dataset, metrics, transformers, per_task_metrics, use_sample_weights, n_classes)
#     218         per_task_metrics=per_task_metrics,
#     219         use_sample_weights=use_sample_weights,
# --> 220         n_classes=n_classes)
#     221
# ...

# %%
model_list=[
      'rf', 'tf', 'tf_robust', 'logreg', 'irv', 'graphconv', 'dag', 'xgb',
      'weave', 'kernelsvm', 'textcnn', 'mpnn'
  ]
