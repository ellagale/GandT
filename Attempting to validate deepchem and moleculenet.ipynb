# %%
# lets load our libraries
#!conda install -y -c conda-forge numpy=1.19.5
import deepchem as dc
from rdkit import Chem
from rdkit.Chem import Draw
import tensorflow as tf
import os
import sys
import rdkit
import h5py

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.tri 
import rdkit.Chem
import rdkit.Chem.AllChem as Chem
import rdkit.Chem.AllChem as AllChem
from rdkit.Chem import Descriptors
from rdkit.Chem import rdMolDescriptors
import mpl_toolkits.mplot3d
from sklearn.ensemble import RandomForestRegressor
from sklearn.decomposition import PCA
from collections import Counter

print("TensorFlow version: " + tf.__version__)
print("DeepChem version: " + dc.__version__)

# topology stuff 
from gtda.plotting import plot_point_cloud
from gtda.homology import VietorisRipsPersistence
from gtda.plotting import plot_diagram
from gtda.diagrams import PersistenceEntropy
from gtda.diagrams import NumberOfPoints
from gtda.diagrams import Amplitude
from sklearn.pipeline import make_union, Pipeline

# fixc this at some point
sys.path.append(r"C:\Users\ella_\Documents\GitHub\graphs_and_topology_for_chemistry")
sys.path.append(r"C:\Users\ella_\Documents\GitHub\icosahedron_projection")

import projection
from projection.molecule import Molecule
from projection.pdbmolecule import PDBMolecule
from projection.mol2molecule import Mol2Molecule

import helper_functions as h
#from projection.face import Face
# Out:
# TensorFlow version: 1.15.0
# DeepChem version: 2.3.0

# %%
import dc.deepchem.molnet.ru
# Out:
#   File "<ipython-input-4-2a04fe23fa60>", line 1
#     import dc.deepchem.molnet.run_benchmark()
#                                            ^
# SyntaxError: invalid syntax

# %%
dc.deepchem.molnet.run_benchmark(datasets=['delaney','PDBBind','qm7','qm8'],
                  model=['tf_regression'],
                  split=None,
                  metric=None,
                  direction=True,
                  featurizer=None,
                  n_features=0,
                  out_path='.',
                  hyper_parameters=None,
                  hyper_param_search=False,
                  max_iter=20,
                  search_range=2,
                  test=True,
                  reload=True,
                  seed=123)
# Out:
# -------------------------------------
# Benchmark on dataset: delaney
# -------------------------------------
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from C:\Users\ella_\AppData\Local\Temp\delaney-processed.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-10d36c369ed7> in <module>
#      13                   test=True,
#      14                   reload=True,
# ---> 15                   seed=123)
#
# C:\ProgramData\Anaconda3\envs\graphs_and_topology_for_chemistry\lib\site-packages\deepchem\molnet\run_benchmark.py in run_benchmark(datasets, model, split, metric, direction, featurizer, n_features, out_path, hyper_parameters, hyper_param_search, max_iter, search_range, test, reload, seed)
#     158     else:
#     159       tasks, all_dataset, transformers = loading_functions[dataset](
# --> 160           featurizer=featurizer, reload=reload)
#     161
#     162     train_dataset, valid_dataset, test_dataset = all_dataset
#
# C:\ProgramData\Anaconda3\envs\graphs_and_topology_for_chemistry\lib\site-packages\deepchem\molnet\load_function\delaney_datasets.py in load_delaney(featurizer, split, reload, move_mean, data_dir, save_dir, **kwargs)
#      69   loader = deepchem.data.CSVLoader(
#      70       tasks=delaney_tasks, smiles_field="smiles", featurizer=featurizer)
# ---> 71   dataset = loader.featurize(dataset_file, shard_size=8192)
#      72
#      73   if split is None:
#
# C:\ProgramData\Anaconda3\envs\graphs_and_topology_for_chemistry\lib\site-packages\deepchem\data\data_loader.py in featurize(self, input_files, data_dir, shard_size)
#     238
#     239     return DiskDataset.create_dataset(
# --> 240         shard_generator(), data_dir, self.tasks, verbose=self.verbose)
#     241
#     242   def get_shards(self, input_files, shard_size):
#
# C:\ProgramData\Anaconda3\envs\graphs_and_topology_for_chemistry\lib\site-packages\deepchem\data\datasets.py in create_dataset(shard_generator, data_dir, tasks, verbose)
#     566     metadata_rows = []
#     567     time1 = time.time()
# --> 568     for shard_num, (X, y, w, ids) in enumerate(shard_generator):
#     569       basename = "shard-%d" % shard_num
#     570       metadata_rows.append(
#
# C:\ProgramData\Anaconda3\envs\graphs_and_topology_for_chemistry\lib\site-packages\deepchem\data\data_loader.py in shard_generator()
#     216           self.get_shards(input_files, shard_size)):
#     217         time1 = time.time()
# --> 218         X, valid_inds = self.featurize_shard(shard)
#     219         ids = shard[self.id_field].values
#     220         ids = ids[valid_inds]
#
# C:\ProgramData\Anaconda3\envs\graphs_and_topology_for_chemistry\lib\site-packages\deepchem\data\data_loader.py in featurize_shard(self, shard)
#     260   def featurize_shard(self, shard):
#     261     """Featurizes a shard of an input dataframe."""
# --> 262     return featurize_smiles_df(shard, self.featurizer, field=self.smiles_field)
#     263
#     264
#
# C:\ProgramData\Anaconda3\envs\graphs_and_topology_for_chemistry\lib\site-packages\deepchem\data\data_loader.py in featurize_smiles_df(df, featurizer, field, log_every_N, verbose)
#      76     if ind % log_every_N == 0:
#      77       log("Featurizing sample %d" % ind, verbose)
# ---> 78     features.append(featurizer.featurize([mol]))
#      79   valid_inds = np.array(
#      80       [1 if elt.size > 0 else 0 for elt in features], dtype=bool)
#
# AttributeError: 'NoneType' object has no attribute 'featurize'
