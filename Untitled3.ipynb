# %%
411/2000
# Out:
# 0.2055

# %%
n = 300 # number
unit_cost = 111# 
leverage = 300 
result = 32

total_cost = n*unit_cost
print(f'total cost = {total_cost}')
margin = total_cost/leverage
print(f'margin = {margin}')
percentage = 100*(result/total_cost )
print(f'percentage profit on total = {percentage} %')
margin_percentage = 100*(result/margin)
print(f'percentage profit on margin = {margin_percentage} %')
# Out:
# total cost = 33300
# margin = 111.0
# percentage profit on total = 0.0960960960960961 %
# percentage profit on margin = 28.82882882882883 %

# %%
542/2000
# Out:
# 0.271
