# %%
# lets load our libraries
#!conda install -y -c conda-forge numpy=1.19.5
import deepchem as dc
from rdkit import Chem
from rdkit.Chem import Draw
import tensorflow as tf
import os
import sys
import rdkit
import h5py

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.tri 
import rdkit.Chem
import rdkit.Chem.AllChem as Chem
import rdkit.Chem.AllChem as AllChem
from rdkit.Chem import Descriptors
from rdkit.Chem import rdMolDescriptors
import mpl_toolkits.mplot3d
from sklearn.ensemble import RandomForestRegressor
from sklearn.decomposition import PCA
from collections import Counter

print("TensorFlow version: " + tf.__version__)

# topology stuff 
from gtda.plotting import plot_point_cloud
from gtda.homology import VietorisRipsPersistence
from gtda.plotting import plot_diagram
from gtda.diagrams import PersistenceEntropy
from gtda.diagrams import NumberOfPoints
from gtda.diagrams import Amplitude
from sklearn.pipeline import make_union, Pipeline

# fixc this at some point
sys.path.append(r"C:\Users\ella_\Documents\GitHub\graphs_and_topology_for_chemistry")
sys.path.append(r"C:\Users\ella_\Documents\GitHub\icosahedron_projection")

import projection
from projection.molecule import Molecule
from projection.pdbmolecule import PDBMolecule
from projection.mol2molecule import Mol2Molecule

import helper_functions as h
#from projection.face import Face
# Out:
# C:\ProgramData\Anaconda3\envs\graphs_and_topology_for_chemistry\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# TensorFlow version: 1.15.0

# %%
# $UN THIS 
save_dir=r'F:\Nextcloud\science\Datasets\converted_pdbbind\v2015'
data_dir=r'F:\Nextcloud\science\Datasets\pdbbind\v2015'
results_dir=r"F:\Nextcloud\science\results\topology_and_graphs\PDBBind"
test_file='1a1c_pocket.pdb'
test_file_ligand='1a1c_ligand.mol2'
test_pdb_code='1a1c'
out_file_name='PDBBind_core_topological_features.hdf5'
make_dataset=False # whether to recalc the dataset

# %%
import deepchem as dc
featurizer = dc.feat.RdkitGridFeaturizer(voxel_width=2.0, sanitize=True, flatten=True,
                                         feature_types=['hbond', 'salt_bridge', 'pi_stack', 'cation_pi', 'ecfp', 'splif'])
pdbbind_tasks, pdbbind_datasets, transformers = dc.molnet.load_pdbbind(featurizer=featurizer, split="random", subset="core")
train_dataset, valid_dataset, test_dataset = pdbbind_datasets
# Out:
# Dataset does not exist at C:\Users\ella_\AppData\Local\Temp\from-pdbbind\full_protein-core-<deepchem.feat.rdkit_grid_featurizer.RdkitGridFeaturizer object at 0x000002420B220A08>-random. Reconstructing...
#
# Raw dataset:
# C:\Users\ella_\AppData\Local\Temp\pdbbind\v2015
#
# Featurized and splitted dataset:
# C:\Users\ella_\AppData\Local\Temp\from-pdbbind\full_protein-core-<deepchem.feat.rdkit_grid_featurizer.RdkitGridFeaturizer object at 0x000002420B220A08>-random
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-27446e6ebc9f> in <module>
#       2 featurizer = dc.feat.RdkitGridFeaturizer(voxel_width=2.0, sanitize=True, flatten=True,
#       3                                          feature_types=['hbond', 'salt_bridge', 'pi_stack', 'cation_pi', 'ecfp', 'splif'])
# ----> 4 pdbbind_tasks, pdbbind_datasets, transformers = dc.molnet.load_pdbbind(featurizer=featurizer, split="random", subset="core")
#       5 train_dataset, valid_dataset, test_dataset = pdbbind_datasets
#
# C:\ProgramData\Anaconda3\envs\graphs_and_topology_for_chemistry\lib\site-packages\deepchem\molnet\load_function\pdbbind_datasets.py in load_pdbbind(reload, data_dir, subset, load_binding_pocket, featurizer, split, split_seed, save_dir, save_timestamp)
#     309           batch_size=64)
#     310   else:
# --> 311     raise ValueError("Featurizer not supported")
#     312
#     313   print("\nFeaturizing Complexes for \"%s\" ...\n" % data_folder)
#
# ValueError: Featurizer not supported

# %%
#featurizer = dc.feat.ContactCircularFingerprint(size=2048)
#features = fp_featurizer.featurize(zip(ligands, proteins))
#dataset = dc.data.NumpyDataset(X=features, y=labels, ids=pdbids)
featurizer = dc.feat.RdkitGridFeaturizer(voxel_width=2.0, sanitize=True, flatten=True,
                                         feature_types=['hbond', 'salt_bridge', 'pi_stack', 'cation_pi', 'ecfp', 'splif'])
tasks, datasets, transformers = dc.molnet.load_pdbbind(
    featurizer="grid",
    split="random",
    subset="refined")
train_dataset, valid_dataset, test_dataset = datasets
# Out:
# Dataset does not exist at C:\Users\ella_\AppData\Local\Temp\from-pdbbind\full_protein-refined-grid-random. Reconstructing...
#
# Raw dataset:
# C:\Users\ella_\AppData\Local\Temp\pdbbind\v2015
#
# Featurized and splitted dataset:
# C:\Users\ella_\AppData\Local\Temp\from-pdbbind\full_protein-refined-grid-random
#
# Featurizing Complexes for "C:\Users\ella_\AppData\Local\Temp\pdbbind\v2015" ...
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\graphs_and_topology_for_chemistry\lib\multiprocessing\pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "C:\ProgramData\Anaconda3\envs\graphs_and_topology_for_chemistry\lib\site-packages\deepchem\feat\base_classes.py", line 16, in _featurize_complex
#     return featurizer._featurize_complex(mol_pdb_file, protein_pdb_file)
#   File "C:\ProgramData\Anaconda3\envs\graphs_and_topology_for_chemistry\lib\site-packages\deepchem\feat\rdkit_grid_featurizer.py", line 1243, in _featurize_complex
#     protein_pdb_file, calc_charges=True, sanitize=self.sanitize)
#   File "C:\ProgramData\Anaconda3\envs\graphs_and_topology_for_chemistry\lib\site-packages\deepchem\utils\rdkit_util.py", line 120, in load_molecule
#     str(molecule_file), sanitize=False, removeHs=False)
# OSError: Bad input file C:\Users\ella_\AppData\Local\Temp\pdbbind\v2015\3g2y\3g2y_protein.pdb
# """
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-006a406f561c> in <module>
#       7     featurizer="grid",
#       8     split="random",
# ----> 9     subset="refined")
#      10 train_dataset, valid_dataset, test_dataset = datasets
#
# C:\ProgramData\Anaconda3\envs\graphs_and_topology_for_chemistry\lib\site-packages\deepchem\molnet\load_function\pdbbind_datasets.py in load_pdbbind(reload, data_dir, subset, load_binding_pocket, featurizer, split, split_seed, save_dir, save_timestamp)
#     314   feat_t1 = time.time()
#     315   features, failures = featurizer.featurize_complexes(ligand_files,
# --> 316                                                       protein_files)
#     317   feat_t2 = time.time()
#     318   print("\nFeaturization finished, took %0.3f s." % (feat_t2 - feat_t1))
#
# C:\ProgramData\Anaconda3\envs\graphs_and_topology_for_chemistry\lib\site-packages\deepchem\feat\base_classes.py in featurize_complexes(self, mol_files, protein_pdbs)
#      51     failures = []
#      52     for ind, result in enumerate(results):
# ---> 53       new_features = result.get()
#      54       # Handle loading failures which return None
#      55       if new_features is not None:
#
# C:\ProgramData\Anaconda3\envs\graphs_and_topology_for_chemistry\lib\multiprocessing\pool.py in get(self, timeout)
#     655             return self._value
#     656         else:
# --> 657             raise self._value
#     658
#     659     def _set(self, i, obj):
#
# OSError: Bad input file C:\Users\ella_\AppData\Local\Temp\pdbbind\v2015\3g2y\3g2y_protein.pdb
